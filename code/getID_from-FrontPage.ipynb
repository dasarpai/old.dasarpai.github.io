# %%
def get_PageId(filename, verbose=False):
    f = open(folder+filename, "rt", encoding="utf8")
    # read all lines
    all_lines = f.readlines(0)
    f.close()

    line_no=0

    
    for l in all_lines:
        if l[0:2]=="id":
            if verbose:
                print(l[:-1], filename)
            id = 0
            try:
                id = int(l[3:][:-1])
            finally:
                return id #l[3:][:-2]
            # print (all_lines[1][0:2])
            break

# %%
folder = r"../_dsblog/"
import os
ids=[]
for file in os.listdir(folder):
    if (file[-2:]=="md"):
        ids.append(get_PageId(file, verbose=True))

min(ids),max(ids)
# Out:
# id: 6001     2020-03-10-Dealing-with-Sensitive-Data.md
# id: 6002     2020-05-02-100+-AI-Usecases.md
# id: 6003     2020-05-15-What is XAI.md
# id: 6004     2021-03-04-Top-10-Technologies-of-Future.md
# id: 6005     2021-03-31-How-Naive-Bayes-Classifier-Works.md
# id: 101     2021-07-01-DSR-Reinforcement-Learning-Repositories.md
# id: 102     2021-07-02-DSR-Data-Science-Interview-Question-Answers.md
# id: 103     2021-07-03-DSR-Data-Science-Cheatsheets.md
# id: 104     2021-07-04-DSR-Mathematics-in-Data-Science.md
# id: 105     2021-07-05-DSR-Important-AI-Research-Papers.md
# id: 106     2021-07-06-DSR-High-School-Maths-for-Data-Science.md
# id: 107     2021-07-07-DSR-Best-Youtube-Channels-to-Learn-Data-Science.md
# id: 108     2021-07-08-DSR-AI-ML-Conferences-and-Journals.md
# id: 109     2021-07-09-DSR-AI-ML-Blogs.md
# id: 110     2021-07-10-DSR-Best-Resources-to-Learn-Python.md
# id: 111     2021-07-11-DSR-My-Favorite-Chrome-Extensions.md
# ...

# %%
folder = r"../_wiablog/"
import os
ids=[]
for file in os.listdir(folder):
    if (file[-2:]=="md"):
        ids.append(get_PageId(file, verbose=True))

min(ids),max(ids)
# Out:
# id: 5000 2012-01-01-Greetings-For-New-Year-2012.md
# id: 5001 2013-01-01-Greetings-For-New-Year-2013.md
# id: 5004 2015-01-01-Greetings-For-New-Year-2015.md
# id: 5002 2015-11-10-Thirukkural-In-Hindi.md
# id: 5003 2015-12-03-Who-Is-The-Real-Enemy-Of-A-Hindu.md
# id: 5005 2016-01-01-Greetings-For-New-Year-2016.md
# id: 5006 2016-01-08-Understanding-The-Reality-Of-The-World.md
# id: 5009 2016-01-25-Who-Is-The-Doer.md
# id: 5010 2016-02-03-About-Experience.md
# id: 5011 2016-02-25-An-Example-Of-Web-Of-Problems.md
# id: 5012 2016-03-02-About-Shoonya-Zero.md
# id: 5013 2016-03-20-About-Responsibility.md
# id: 5014 2016-04-10-Prisoner-Of-The-Mind.md
# id: 5015 2016-04-12-Mind-And-Pleasure.md
# id: 5016 2016-04-20-The-Way-Of-Mother.md
# id: 5017 2016-05-08-Nectar-For-Society.md
# id: 5018 2016-05-27-Questions-About-Meditation.md
# id: 5019 2016-05-31-About-Astika.md
# id: 5020 2016-06-08-About-Peace-Or-The-Peace.md
# id: 5021 2016-06-24-Gate-Of-Mind.md
# ...

# %%
folder = r"../_pages/"
import os
ids=[]
for file in os.listdir(folder):
    if (file[-2:]=="md"):
        ids.append(get_PageId(file, verbose=True))

min(ids),max(ids)
# Out:
# id: 701     aboutme.md
# id: 742     booksummary-blog.md
# id: 702     clients.md
# id: 741     comment-policy.md
# id: 743     corpus-home.md
# id: 703     datascience-blog.md
# id: 704     datascience-courses.md
# id: 705     datascience-resources.md
# id: 706     datascience-tags.md
# id: 741     dslexicon.md
# id: 741     gk-blog.md
# id: 742     gk-tags.md
# id: 741     management.md
# id: 708     micorosoft-pm-templates.md
# id: 709     pmbok6-summary.md
# id: 710     pmbok6-tags.md
# id: 711     pmbok6.md
# id: 712     pmbok6hi-summary.md
# id: 713     pmbok6hi-tags.md
# id: 714     pmbok6hi.md
# id: 715     pmglossary.md
# id: 716     pmi-templates.md
# id: 717     pmlogy-blog.md
# id: 718     pmlogy-home.md
# id: 719     pmlogy-tags.md
# id: 720     prince2-templates.md
# id: 745     privacy-policy.md
# id: 742     publications-home.md
# id: 741     quotations-blog.md
# id: 723     quotations-tags.md
# id: 721     samskrut-blog.md
# id: 722     samskrut-home.md
# ...
