# %%
folder+file
# Out:
# '../_wiablog/12024-10-06-Insights-from-the-First-Chapter-of-Durga-Saptashati-Hindi.md'

# %%
l[0:11]=="categories:"
# Out:
# True

# %%
folder = r"../_wiablog/"
import os
# ids=[]
all_lines=[]
for file in os.listdir(folder):
    if (file[-2:]=="md"):
        with open(folder+file, "rt", encoding="utf8") as f:
            all_lines = f.readlines(0)
        
        i=0
        for l in all_lines:
            if l[0:11]=="categories:":
                print (l)

                # print (urlfrom, "=>",urlto)
                replaced_line = "categories: [wiaposts] \n"
                # print (replaced_line)
                all_lines[i] = replaced_line
                # "permalink: " + l[10:]
                # id = int(l[3:][:-1])
                break
            i+=1   
            # redirect_from:
        # print(all_lines)
        with open(folder+file, "wt", encoding="utf8") as f:
            f.writelines(all_lines)
# Out:
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# categories: [wiablog]
#
# ...

# %%
folder = r"../_wiablog/"
import os
# ids=[]
all_lines=[]
for file in os.listdir(folder):
    if (file[-2:]=="md"):
        with open(folder+file, "rt", encoding="utf8") as f:
            all_lines = f.readlines(0)
        
        i=0
        for l in all_lines:
            if l[0:10]=="permalink:":
                url = l.split(":")[1].strip()
                url1= url[10:]
                urlto = "/samskrutyatra" + url1
                urlfrom = url 

                # print (urlfrom, "=>",urlto)
                replaced_line = "permalink: " + urlto + "\n" + "redirect_from: \n  - " + urlfrom + "\n"
                # print (replaced_line)
                all_lines[i] = replaced_line
                # "permalink: " + l[10:]
                # id = int(l[3:][:-1])
                break
            i+=1   
            # redirect_from:
        print(all_lines)
        # with open(folder+file, "wt", encoding="utf8") as f:
        #     f.writelines(all_lines)
